# %% [markdown]
# <a href="https://colab.research.google.com/github/gurpreet-vilkhoo/Human-Resources-Retention/blob/main/Human_Resources_Retention.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Retention Study - Figuring Out Which Employees May Quit
# ### Loading our Main HR Database Records

# %%
import pandas as pd

file_name = "https://raw.githubusercontent.com/gurpreet-vilkhoo/Human-Resources-Retention/main/hr_data.csv"
hr_df = pd.read_csv(file_name)

hr_df.head()
# Out:
#    employee_id  number_project  ...  department  salary
# 0         1003               2  ...       sales     low
# 1         1005               5  ...       sales  medium
# 2         1486               7  ...       sales  medium
# 3         1038               5  ...       sales     low
# 4         1057               2  ...       sales     low
#
# [5 rows x 9 columns]

# %%
# View the bottom 5 rows
hr_df.tail()
# Out:
#        employee_id  number_project  ...  department  salary
# 14994        87670               2  ...     support     low
# 14995        87673               2  ...     support     low
# 14996        87679               2  ...     support     low
# 14997        87681               6  ...     support     low
# 14998        87684               2  ...     support     low
#
# [5 rows x 9 columns]

# %%
hr_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14999 entries, 0 to 14998
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   employee_id            14999 non-null  int64
#  1   number_project         14999 non-null  int64
#  2   average_montly_hours   14999 non-null  int64
#  3   time_spend_company     14999 non-null  int64
#  4   Work_accident          14999 non-null  int64
#  5   left                   14999 non-null  int64
#  6   promotion_last_5years  14999 non-null  int64
#  7   department             14999 non-null  object
#  8   salary                 14999 non-null  object
# dtypes: int64(7), object(2)
# memory usage: 1.0+ MB

# %%
# View which columns are categorical
hr_df.select_dtypes(exclude=['int', 'float']).columns
# Out:
# Index(['department', 'salary'], dtype='object')

# %%
# Display values in categorical columns
print(hr_df['department'].unique())
print(hr_df['salary'].unique())
# Out:
# ['sales' 'accounting' 'hr' 'technical' 'support' 'management' 'IT'
#  'product_mng' 'marketing' 'RandD']
# ['low' 'medium' 'high']

# %%
# How many rows are in our dataset?
len(hr_df)
# Out:
# 14999

# %%
# What about how many columns?
len(hr_df.columns)
# Out:
# 9

# %%
hr_df.shape
# Out:
# (14999, 9)

# %% [markdown]
# ### Loading our Evaluation and Employee Satisfaction Data

# %%
file_name = "https://raw.githubusercontent.com/gurpreet-vilkhoo/Human-Resources-Retention/main/employee_satisfaction.xlsx"
emp_satis_eval = pd.read_excel(file_name)

emp_satis_eval.head()
# Out:
#    EMPLOYEE #  satisfaction_level  last_evaluation
# 0        1003                0.38             0.53
# 1        1005                0.80             0.86
# 2        1486                0.11             0.88
# 3        1038                0.72             0.87
# 4        1057                0.37             0.52

# %%
emp_satis_eval.shape
# Out:
# (14999, 3)

# %% [markdown]
# ### Merge or Join Tables

# %%
main_df = hr_df.set_index('employee_id').join(emp_satis_eval.set_index('EMPLOYEE #'))
main_df = main_df.reset_index()
main_df.head()
# Out:
#    employee_id  number_project  ...  satisfaction_level  last_evaluation
# 0         1003               2  ...                0.38             0.53
# 1         1005               5  ...                0.80             0.86
# 2         1486               7  ...                0.11             0.88
# 3         1038               5  ...                0.72             0.87
# 4         1057               2  ...                0.37             0.52
#
# [5 rows x 11 columns]

# %% [markdown]
# Are there missing values?

# %%
#main_df.isnull()
main_df[main_df.isnull().any(axis=1)]
# Out:
#        employee_id  number_project  ...  satisfaction_level  last_evaluation
# 18            3794               2  ...                 NaN              NaN
# 19            1140               5  ...                 NaN             0.89
# 33            1230               2  ...                 NaN              NaN
# 53            1340               2  ...                 NaN              NaN
# 72           22316               2  ...                 NaN              NaN
# 92            1581               2  ...                 NaN              NaN
# 107          17376               2  ...                 NaN              NaN
# 120           1739               4  ...                 NaN              NaN
# 137           1847               2  ...                 NaN              NaN
# 175          32923               4  ...                 NaN              NaN
# 191           2160               4  ...                0.92              NaN
# 352           3150               4  ...                 NaN             0.91
# 376           3250               4  ...                0.56              NaN
# 402           3405               5  ...                 NaN             1.00
# 427          78130               3  ...                 NaN             0.60
# 442           3635               5  ...                0.77              NaN
# 468           3755               5  ...                 NaN             0.92
# 543           4150               5  ...                0.89              NaN
# 892          43615               4  ...                0.74              NaN
# 1588         42185               5  ...                 NaN             0.81
# 1934         11895               4  ...                0.78              NaN
# 2343         14170               3  ...                 NaN             0.97
# 2743         16445               5  ...                0.62              NaN
# 3170         18980               5  ...                 NaN              NaN
# 3609         21580               3  ...                0.95              NaN
# 3776         22555               4  ...                 NaN             0.68
# 4122         24505               3  ...                0.86              NaN
# 4740         27950               3  ...                 NaN             0.95
# 5028         29640               4  ...                0.64              NaN
# 6453         38090               5  ...                 NaN             0.78
# 7005         41535               4  ...                0.82              NaN
# 7516         44460               4  ...                 NaN             0.97
# 8630         50960               4  ...                0.90              NaN
# 9455         55770               4  ...                 NaN             0.88
# 9901         58630               5  ...                0.92              NaN
# 10647        62595               4  ...                 NaN             0.69
# 10962        64350               5  ...                0.65              NaN
# 11575        20215               3  ...                 NaN              NaN
# 11967        70005               3  ...                0.82              NaN
# 12422        72475               5  ...                 NaN             1.00
# 12853        74880               3  ...                 NaN             0.70
# 13482        78780               3  ...                0.58              NaN
# 13925        81315               3  ...                 NaN             0.75
#
# [43 rows x 11 columns]

# %% [markdown]
# ### Let's fill in the missing blanks with the average values

# %%
main_df.describe()
# Out:
#         employee_id  number_project  ...  satisfaction_level  last_evaluation
# count  14999.000000    14999.000000  ...        14972.000000     14972.000000
# mean   45424.627575        3.803054  ...            0.612830         0.716125
# std    25915.900127        1.232592  ...            0.248714         0.171138
# min     1003.000000        2.000000  ...            0.090000         0.360000
# 25%    22872.500000        3.000000  ...            0.440000         0.560000
# 50%    45448.000000        4.000000  ...            0.640000         0.720000
# 75%    67480.500000        5.000000  ...            0.820000         0.870000
# max    99815.000000        7.000000  ...            1.000000         1.000000
#
# [8 rows x 9 columns]

# %%
main_df.fillna(main_df.mean(), inplace=True)
main_df.head()
# Out:
#    employee_id  number_project  ...  satisfaction_level  last_evaluation
# 0         1003               2  ...                0.38             0.53
# 1         1005               5  ...                0.80             0.86
# 2         1486               7  ...                0.11             0.88
# 3         1038               5  ...                0.72             0.87
# 4         1057               2  ...                0.37             0.52
#
# [5 rows x 11 columns]

# %%
#main_df[main_df.employee_id == 3794]
main_df.loc[main_df['employee_id'] == 3794]
# Out:
#     employee_id  number_project  ...  satisfaction_level  last_evaluation
# 18         3794               2  ...             0.61283         0.716125
#
# [1 rows x 11 columns]

# %%
main_df.head()
# Out:
#    employee_id  number_project  ...  satisfaction_level  last_evaluation
# 0         1003               2  ...                0.38             0.53
# 1         1005               5  ...                0.80             0.86
# 2         1486               7  ...                0.11             0.88
# 3         1038               5  ...                0.72             0.87
# 4         1057               2  ...                0.37             0.52
#
# [5 rows x 11 columns]

# %%
# Removing employee ID
main_df_final = main_df.drop(columns='employee_id')
main_df_final.head()
# Out:
#    number_project  average_montly_hours  ...  satisfaction_level  last_evaluation
# 0               2                   157  ...                0.38             0.53
# 1               5                   262  ...                0.80             0.86
# 2               7                   272  ...                0.11             0.88
# 3               5                   223  ...                0.72             0.87
# 4               2                   159  ...                0.37             0.52
#
# [5 rows x 10 columns]

# %%
main_df_final.groupby('department').sum()
# Out:
#              number_project  ...  last_evaluation
# department                   ...
# IT                     4683  ...       879.452250
# RandD                  3033  ...       560.446125
# accounting             2934  ...       550.706125
# hr                     2701  ...       524.006125
# management             2432  ...       456.234499
# marketing              3164  ...       613.946125
# product_mng            3434  ...       644.662250
# sales                 15634  ...      2938.236749
# support                8479  ...      1611.534499
# technical             10548  ...      1961.930624
#
# [10 rows x 8 columns]

# %%
main_df_final.groupby('department').mean()
# Out:
#              number_project  ...  last_evaluation
# department                   ...
# IT                 3.816626  ...         0.716750
# RandD              3.853875  ...         0.712130
# accounting         3.825293  ...         0.718000
# hr                 3.654939  ...         0.709075
# management         3.860317  ...         0.724182
# marketing          3.687646  ...         0.715555
# product_mng        3.807095  ...         0.714703
# sales              3.776329  ...         0.709719
# support            3.803948  ...         0.722985
# technical          3.877941  ...         0.721298
#
# [10 rows x 8 columns]

# %%
main_df_final['department'].value_counts()
# Out:
# sales          4140
# technical      2720
# support        2229
# IT             1227
# product_mng     902
# marketing       858
# RandD           787
# accounting      767
# hr              739
# management      630
# Name: department, dtype: int64

# %%
main_df_final['left'].value_counts()
# Out:
# 0    11428
# 1     3571
# Name: left, dtype: int64

# %% [markdown]
# ## Preparing out  Dataset for ML

# %%
# Perform One Hot Encoding on Categorical Data

categorial = ['department','salary']
main_df_final = pd.get_dummies(main_df_final, columns=categorial, drop_first=True)
main_df_final.head()
# Out:
#    number_project  average_montly_hours  ...  salary_low  salary_medium
# 0               2                   157  ...           1              0
# 1               5                   262  ...           0              1
# 2               7                   272  ...           0              1
# 3               5                   223  ...           1              0
# 4               2                   159  ...           1              0
#
# [5 rows x 19 columns]

# %%
# How many columns do we now have?

len(main_df_final.columns)
# Out:
# 19

# %%
# How many employees in the dataset have left?

len(main_df_final.loc[main_df_final['left'] == 1])
# Out:
# 3571

# %%
main_df_final.head()
# Out:
#    number_project  average_montly_hours  ...  salary_low  salary_medium
# 0               2                   157  ...           1              0
# 1               5                   262  ...           0              1
# 2               7                   272  ...           0              1
# 3               5                   223  ...           1              0
# 4               2                   159  ...           1              0
#
# [5 rows x 19 columns]

# %%
main_df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14999 entries, 0 to 14998
# Data columns (total 19 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   number_project          14999 non-null  int64
#  1   average_montly_hours    14999 non-null  int64
#  2   time_spend_company      14999 non-null  int64
#  3   Work_accident           14999 non-null  int64
#  4   left                    14999 non-null  int64
#  5   promotion_last_5years   14999 non-null  int64
#  6   satisfaction_level      14999 non-null  float64
#  7   last_evaluation         14999 non-null  float64
#  8   department_RandD        14999 non-null  uint8
#  9   department_accounting   14999 non-null  uint8
#  10  department_hr           14999 non-null  uint8
#  11  department_management   14999 non-null  uint8
#  12  department_marketing    14999 non-null  uint8
#  13  department_product_mng  14999 non-null  uint8
#  14  department_sales        14999 non-null  uint8
#  15  department_support      14999 non-null  uint8
#  16  department_technical    14999 non-null  uint8
#  17  salary_low              14999 non-null  uint8
#  18  salary_medium           14999 non-null  uint8
# dtypes: float64(2), int64(6), uint8(11)
# memory usage: 1.1 MB

# %% [markdown]
# ## Preparing our Dataset for Machine Learning

# %%
from sklearn.model_selection import train_test_split

# We remove the label values from our training data
X = main_df_final.drop(['left'],axis=1).values

# We assigned those label values to our Y dataset
y = main_df_final['left'].values

# %%
# Split it to a 70:30 Ratio Train:Test

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %%
# Normalize the data
from sklearn.preprocessing import StandardScaler

sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
df_train = pd.DataFrame(X_train)
df_train.head()
# Out:
#          0         1         2   ...        15        16        17
# 0 -0.646210  1.446235 -0.340590  ... -0.463097  1.027328 -0.871330
# 1  0.973984  0.423087 -1.024834  ... -0.463097  1.027328 -0.871330
# 2  0.973984  1.185433 -0.340590  ... -0.463097  1.027328 -0.871330
# 3 -1.456307 -1.723518 -0.340590  ... -0.463097 -0.973399  1.147671
# 4  0.163887  1.285741  0.343653  ... -0.463097 -0.973399  1.147671
#
# [5 rows x 18 columns]

# %%
df_train.describe()
# Out:
#                  0             1   ...            16            17
# count  1.049900e+04  1.049900e+04  ...  1.049900e+04  1.049900e+04
# mean  -3.802612e-17 -2.454831e-16  ...  7.923095e-16  7.032082e-18
# std    1.000048e+00  1.000048e+00  ...  1.000048e+00  1.000048e+00
# min   -1.456307e+00 -2.104691e+00  ... -9.733987e-01 -8.713299e-01
# 25%   -6.462103e-01 -9.009875e-01  ... -9.733987e-01 -8.713299e-01
# 50%    1.638866e-01 -1.827129e-02  ... -9.733987e-01 -8.713299e-01
# 75%    9.739836e-01  8.845066e-01  ...  1.027328e+00  1.147671e+00
# max    2.594177e+00  2.188519e+00  ...  1.027328e+00  1.147671e+00
#
# [8 rows x 18 columns]

# %% [markdown]
# ##  Logistic Regression Model

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score

model = LogisticRegression(solver='lbfgs')
model.fit(X_train, y_train)

predictions = model.predict(X_test)

print("Accuracy {0:.2f}%".format(100*accuracy_score(predictions, y_test)))
print(confusion_matrix(y_test, predictions))
print(classification_report(y_test, predictions))
# Out:
# Accuracy 79.13%
# [[3167  227]
#  [ 712  394]]
#               precision    recall  f1-score   support
#
#            0       0.82      0.93      0.87      3394
#            1       0.63      0.36      0.46      1106
#
#     accuracy                           0.79      4500
#    macro avg       0.73      0.64      0.66      4500
# weighted avg       0.77      0.79      0.77      4500

# %% [markdown]
# ### Random Forest Classifer

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score

model = RandomForestClassifier()
model.fit(X_train, y_train)

predictions = model.predict(X_test)
score = model.score(X_test, y_test)

print("Accuracy {0:.2f}%".format(100*accuracy_score(predictions, y_test)))
print(confusion_matrix(y_test, predictions))
print(classification_report(y_test, predictions))
# Out:
# Accuracy 98.89%
# [[3388    6]
#  [  44 1062]]
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      3394
#            1       0.99      0.96      0.98      1106
#
#     accuracy                           0.99      4500
#    macro avg       0.99      0.98      0.98      4500
# weighted avg       0.99      0.99      0.99      4500

# %%
hr_df.head()
# Out:
#    employee_id  number_project  ...  department  salary
# 0         1003               2  ...       sales     low
# 1         1005               5  ...       sales  medium
# 2         1486               7  ...       sales  medium
# 3         1038               5  ...       sales     low
# 4         1057               2  ...       sales     low
#
# [5 rows x 9 columns]

# %%
main_df_final.drop(['left'],axis=1).columns
# Out:
# Index(['number_project', 'average_montly_hours', 'time_spend_company',
#        'Work_accident', 'promotion_last_5years', 'satisfaction_level',
#        'last_evaluation', 'department_RandD', 'department_accounting',
#        'department_hr', 'department_management', 'department_marketing',
#        'department_product_mng', 'department_sales', 'department_support',
#        'department_technical', 'salary_low', 'salary_medium'],
#       dtype='object')

# %%
import pandas as pd
feature_importances = pd.DataFrame(model.feature_importances_,
                                   index = pd.DataFrame(X_train).columns,
                                    columns=['importance']).sort_values('importance',ascending=False)

feature_importances
# Out:
#     importance
# 5     0.302105
# 0     0.204058
# 2     0.178079
# 1     0.152255
# 6     0.119712
# 3     0.010147
# 16    0.008946
# 15    0.003998
# 17    0.003934
# 13    0.003882
# 14    0.002710
# 10    0.001796
# 8     0.001579
# 7     0.001499
# 4     0.001446
# 9     0.001375
# 11    0.001298
# 12    0.001180

# %% [markdown]
# ### Deep Learning

# %%
# Use the newest version of TensorFlow 2.0
# %tensorflow_version 2.x

# %%
import tensorflow.keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

model = Sequential()

model.add(Dense(9, kernel_initializer = "uniform", activation = "relu", input_dim=18))
model.add(Dense(1, kernel_initializer = "uniform", activation = "sigmoid"))

model.compile(optimizer= "adam",loss = "binary_crossentropy",metrics = ["accuracy"])

# %%
# Display Model Summary and Show Parameters
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 9)                 171
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 10
# =================================================================
# Total params: 181
# Trainable params: 181
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Start Training Our Classifier 
batch_size = 10
epochs = 30

history = model.fit(X_train,
                    y_train,
                    batch_size = batch_size,
                    epochs = epochs,
                    verbose = 1,
                    validation_data = (X_test, y_test))

score = model.evaluate(X_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Epoch 1/30
# 1050/1050 [==============================] - 3s 2ms/step - loss: 0.5335 - accuracy: 0.7764 - val_loss: 0.3289 - val_accuracy: 0.8182
# Epoch 2/30
# 1050/1050 [==============================] - 2s 2ms/step - loss: 0.2996 - accuracy: 0.8321 - val_loss: 0.2574 - val_accuracy: 0.8538
# Epoch 3/30
# 1050/1050 [==============================] - 2s 2ms/step - loss: 0.2442 - accuracy: 0.8784 - val_loss: 0.2227 - val_accuracy: 0.9400
# Epoch 4/30
# 1050/1050 [==============================] - 2s 2ms/step - loss: 0.2165 - accuracy: 0.9476 - val_loss: 0.2045 - val_accuracy: 0.9469
# Epoch 5/30
# 1050/1050 [==============================] - 2s 2ms/step - loss: 0.1925 - accuracy: 0.9545 - val_loss: 0.1927 - val_accuracy: 0.9527
# Epoch 6/30
# 1050/1050 [==============================] - 2s 2ms/step - loss: 0.1843 - accuracy: 0.9575 - val_loss: 0.1868 - val_accuracy: 0.9542
# Epoch 7/30
# 1050/1050 [==============================] - 2s 2ms/step - loss: 0.1708 - accuracy: 0.9614 - val_loss: 0.1836 - val_accuracy: 0.9536
# Epoch 8/30
# 1050/1050 [==============================] - 2s 2ms/step - loss: 0.1718 - accuracy: 0.9572 - val_loss: 0.1758 - val_accuracy: 0.9538
# Epoch 9/30
# 1050/1050 [==============================] - 2s 2ms/step - loss: 0.1721 - accuracy: 0.9562 - val_loss: 0.1742 - val_accuracy: 0.9547
# Epoch 10/30
# 1050/1050 [==============================] - 2s 2ms/step - loss: 0.1754 - accuracy: 0.9548 - val_loss: 0.1750 - val_accuracy: 0.9527
# Epoch 11/30
# 1050/1050 [==============================] - 2s 2ms/step - loss: 0.1687 - accuracy: 0.9571 - val_loss: 0.1732 - val_accuracy: 0.9529
# Epoch 12/30
# 1050/1050 [==============================] - 2s 2ms/step - loss: 0.1503 - accuracy: 0.9608 - val_loss: 0.1729 - val_accuracy: 0.9507
# Epoch 13/30
# 1050/1050 [==============================] - 2s 2ms/step - loss: 0.1463 - accuracy: 0.9594 - val_loss: 0.1702 - val_accuracy: 0.9529
# Epoch 14/30
# 1050/1050 [==============================] - 2s 2ms/step - loss: 0.1590 - accuracy: 0.9546 - val_loss: 0.1715 - val_accuracy: 0.9529
# Epoch 15/30
# 1050/1050 [==============================] - 2s 2ms/step - loss: 0.1669 - accuracy: 0.9545 - val_loss: 0.1723 - val_accuracy: 0.9538
# Epoch 16/30
# 1050/1050 [==============================] - 2s 2ms/step - loss: 0.1485 - accuracy: 0.9584 - val_loss: 0.1702 - val_accuracy: 0.9524
# Epoch 17/30
# 1050/1050 [==============================] - 2s 2ms/step - loss: 0.1604 - accuracy: 0.9550 - val_loss: 0.1698 - val_accuracy: 0.9531
# Epoch 18/30
# 1050/1050 [==============================] - 2s 2ms/step - loss: 0.1579 - accuracy: 0.9551 - val_loss: 0.1674 - val_accuracy: 0.9533
# Epoch 19/30
# 1050/1050 [==============================] - 2s 2ms/step - loss: 0.1488 - accuracy: 0.9592 - val_loss: 0.1665 - val_accuracy: 0.9536
# Epoch 20/30
# 1050/1050 [==============================] - 2s 2ms/step - loss: 0.1519 - accuracy: 0.9579 - val_loss: 0.1703 - val_accuracy: 0.9529
# Epoch 21/30
# 1050/1050 [==============================] - 2s 2ms/step - loss: 0.1557 - accuracy: 0.9580 - val_loss: 0.1682 - val_accuracy: 0.9538
# Epoch 22/30
# 1050/1050 [==============================] - 2s 2ms/step - loss: 0.1555 - accuracy: 0.9562 - val_loss: 0.1688 - val_accuracy: 0.9540
# Epoch 23/30
# 1050/1050 [==============================] - 2s 2ms/step - loss: 0.1580 - accuracy: 0.9544 - val_loss: 0.1662 - val_accuracy: 0.9522
# Epoch 24/30
# 1050/1050 [==============================] - 2s 2ms/step - loss: 0.1404 - accuracy: 0.9609 - val_loss: 0.1682 - val_accuracy: 0.9522
# Epoch 25/30
# 1050/1050 [==============================] - 2s 2ms/step - loss: 0.1468 - accuracy: 0.9581 - val_loss: 0.1680 - val_accuracy: 0.9516
# Epoch 26/30
# 1050/1050 [==============================] - 2s 2ms/step - loss: 0.1513 - accuracy: 0.9586 - val_loss: 0.1655 - val_accuracy: 0.9529
# Epoch 27/30
# 1050/1050 [==============================] - 2s 2ms/step - loss: 0.1604 - accuracy: 0.9544 - val_loss: 0.1659 - val_accuracy: 0.9513
# Epoch 28/30
# 1050/1050 [==============================] - 2s 2ms/step - loss: 0.1549 - accuracy: 0.9545 - val_loss: 0.1650 - val_accuracy: 0.9533
# Epoch 29/30
# 1050/1050 [==============================] - 2s 2ms/step - loss: 0.1486 - accuracy: 0.9574 - val_loss: 0.1645 - val_accuracy: 0.9531
# Epoch 30/30
# 1050/1050 [==============================] - 2s 2ms/step - loss: 0.1589 - accuracy: 0.9560 - val_loss: 0.1661 - val_accuracy: 0.9536
# Test loss: 0.16614341735839844
# Test accuracy: 0.9535555839538574

# %%
# Plotting our loss charts
import matplotlib.pyplot as plt

history_dict = history.history

loss_values = history_dict['loss']
val_loss_values = history_dict['val_loss']
epochs = range(1, len(loss_values) + 1)

line1 = plt.plot(epochs, val_loss_values, label='Validation/Test Loss')
line2 = plt.plot(epochs, loss_values, label='Training Loss')
plt.setp(line1, linewidth=2.0, marker = '+', markersize=10.0)
plt.setp(line2, linewidth=2.0, marker = '4', markersize=10.0)
plt.xlabel('Epochs') 
plt.ylabel('Loss')
plt.grid(True)
plt.legend()
plt.show()

# %%
# Plotting our accuracy charts
import matplotlib.pyplot as plt

history_dict = history.history

acc_values = history_dict['accuracy']
val_acc_values = history_dict['val_accuracy']
epochs = range(1, len(loss_values) + 1)

line1 = plt.plot(epochs, val_acc_values, label='Validation/Test Accuracy')
line2 = plt.plot(epochs, acc_values, label='Training Accuracy')
plt.setp(line1, linewidth=2.0, marker = '+', markersize=10.0)
plt.setp(line2, linewidth=2.0, marker = '4', markersize=10.0)
plt.xlabel('Epochs') 
plt.ylabel('Accuracy')
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# ## Displaying the Classification Report and Confusion Matrix

# %%
predictions = model.predict(X_test)
predictions = (predictions > 0.5)

print(confusion_matrix(y_test, predictions))
print(classification_report(y_test, predictions))
# Out:
# [[3303   91]
#  [ 118  988]]
#               precision    recall  f1-score   support
#
#            0       0.97      0.97      0.97      3394
#            1       0.92      0.89      0.90      1106
#
#     accuracy                           0.95      4500
#    macro avg       0.94      0.93      0.94      4500
# weighted avg       0.95      0.95      0.95      4500
